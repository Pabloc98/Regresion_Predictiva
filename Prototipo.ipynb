# %% [markdown]
# <a href="https://colab.research.google.com/github/bosoriog/Regresion_Predictiva/blob/Dev/Prototipo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Conexión drive y repo Github

# %%
#Elimina Warnings
import warnings

warnings.filterwarnings("ignore")
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd drive/MyDrive/Proyecto_Predictiva
# Out:
# /content/drive/MyDrive/Proyecto_Predictiva

# %%
# !pwd
# Out:
# /content/drive/My Drive/Proyecto_Predictiva/Regresion_Predictiva

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/My Drive/Proyecto_Predictiva' 
# replace with your Github username 
GIT_USERNAME = "bosoriog" 
# definitely replace with your
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "Regresion_Predictiva" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/My Drive/Proyecto_Predictiva
# mkdir: cannot create directory ‘/content/drive/My Drive/Proyecto_Predictiva’: File exists
# GIT_PATH:  https://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@github.com/bosoriog/Regresion_Predictiva.git

# %%
#%cd "{PROJECT_PATH"    # Change directory to the location defined in project_path
# !git clone -b Dev "{GIT_PATH}" # clone the github repository
# Out:
# Cloning into 'Regresion_Predictiva'...
# remote: Enumerating objects: 553, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 553 (delta 79), reused 37 (delta 20), pack-reused 424
# Receiving objects: 100% (553/553), 2.10 MiB | 8.38 MiB/s, done.
# Resolving deltas: 100% (268/268), done.

# %%
cd Regresion_Predictiva/
# Out:
# /content/drive/MyDrive/Proyecto_Predictiva/Regresion_Predictiva

# %%
# !git branch
# Out:
# * Dev

# %% [markdown]
# #Codigo Base del Proyecto

# %%
import Implementation.descriptiva as ini

# %%
x, y = ini.descriptiva()
# Out:
# Inserte el nombre exacto del archivo que contiene los datos incluyendo su extensión: recaudoZER.xlsx
# ----------------------------------------------------------------------------------------
#  --------------------------------HEAD--------------------------------------------
# ----------------------------------------------------------------------------------------
#   Zona  Celda  Valor    Pago       Estado     TIEMPO  Dia  Dia_semana   Fecha
# 0    S     23      0     0.0       CLOSED   9.166667   21           1  737689
# 1    S     22   5500     0.0  CLOSED_DEBT   2.883333   21           1  737689
# 2    Z      6   3000     0.0  CLOSED_DEBT   1.566667   21           1  737689
# 3    V     10      0     0.0       CLOSED   0.083333   21           1  737689
# 4    Z      1   3000  3000.0  CLOSED_PAID   0.283333   21           1  737689
# 5    S     16   2000     0.0  CLOSED_DEBT   1.000000   21           1  737689
# ...

# %%
import Implementation.model_f as mdf

# %%
data_models, Y_test, Y_predict = mdf.model_f(x, y,["SGDRegressor", "KNeighborsRegressor"])
# Out:
# ['modelos', 'escala']
# 2
# iter_2: ---
# minmax
# iter_2: ---
# StandardScaler
# 2
# iter_2: ---
# minmax
# iter_2: ---
# StandardScaler

# %%
data_models
# Out:
#                 modelo          escala           mse        r2  ...  \
# 0         SGDRegressor          minmax  7.399681e+06  0.019073  ...
# 1         SGDRegressor  StandardScaler  6.847473e+06  0.092276  ...
# 2  KNeighborsRegressor  StandardScaler  1.146632e+07 -0.520014  ...
# 3  KNeighborsRegressor          minmax  1.148477e+07 -0.522460  ...
#
#   rank_test_score  param_penalty  param_alpha  param_l1_ratio
# 0             1.0             l2        3e-05             NaN
# 1             2.0             l2        3e-05             NaN
# 2             3.0            NaN          NaN             NaN
# 3             4.0            NaN          NaN             NaN
#
# [4 rows x 24 columns]

# %% [markdown]
# ##Resultados

# %%
import Implementation.results as rs

# %%
rs.results(Y_test, Y_predict)
# Out:
# Mean Squared Error: 7399681.36
# RSquared score: 0.02
